# %%
import numpy as np
import time

# TODO
## transition prob matrix (s,a,s')
## reward matrix (s,a)
## random 환경 구현, random policy 구현, 동기 비동기 for문 구현, matrix 구현, linear equation 구현

# %% [markdown]
# # Env, Random policy

# %%
def env(s, a):
    '''
    Args: 
        state dim, action dim

    Returns: 
        transition prob, reward matrix
    '''
    
    p = np.random.random(s*a*s).reshape(s,a,s)
    p = p / p.sum(axis=2, keepdims=True) 
    r = np.random.random(s*a).reshape(s,a)
    
    return p, r

# class Env:
#     def __init__(self, s, a):
#         self.state_dim = s
#         self.action_dim = a
#         self.current_state = 0  # 초기 상태
#         self._generate_tp_(s, a)
#         self._generate_r_(s, a)
    
#     def _generate_tp_(self, s, a):
#         self.p = np.random.random(s*a*s).reshape(s,a,s)
#         self.p = self.p / self.p.sum(axis=2, keepdims=True) 
    
#     def _generate_r_(self, s, a):
#         self.r = np.random.random(s*a).reshape(s,a)
    
#     def step(self, action):
#         next_state_probs = self.p[self.current_state, action]
#         next_state = np.random.choice(self.state_dim, p=next_state_probs)
#         reward = self.r[self.current_state, action]
#         self.current_state = next_state
#         return next_state, reward
    
#     def reset(self):
#         self.current_state = 0
#         return self.current_state
    
#     def get_dynamics(self):
#         return self.p, self.r
        

def random_policy(s,a):
    '''
    Args: 
        state dim, action dim

    Returns: 
        random policy
    '''
    pi = np.random.random(s*a).reshape(s,a)
    pi = pi / pi.sum(axis=1, keepdims=True)
    return pi

# %% [markdown]
# # Policy Evaluation

# %%
# linear equation(evaluation)
def linear_equation(P,R, policy, gamma=0.9):
    r_pi = np.sum(policy*R, axis=1)
    p_pi = np.sum(policy[:, :,np.newaxis] * P, axis=1)
    V = np.linalg.inv(np.eye(s) - gamma*p_pi) @ r_pi
    return V

# policy evaluation matrix
def policy_evaluation_matrix(p, r, policy, env=None, gamma=0.9, theta=1e-6):
    """
    Args:
        p: transition probability matrix (S x A x S)
        r: reward matrix (S x A)
        policy: policy matrix (S x A)
        gamma: discount factor
        theta: threshold
        
    Returns:
        V: state-value function (S)
    """
    n_states = p.shape[0]
    
    # Initialize value function or random
    V = np.zeros(n_states)
    
    while True:
        # Compute expected rewards for each state (S x 1)
        expected_rewards = np.sum(policy * r, axis=1)
        
        # Compute expected next state values (S x S)
        # p_policy: (S x S) matrix where p_policy[s,s'] = sum_a policy(s,a) * p(s,a,s')
        p_policy = np.sum(policy[:, :, np.newaxis] * p, axis=1)
        
        # Compute new value function
        V_new = expected_rewards + gamma * np.dot(p_policy, V)
        
        # Check for convergence
        if np.max(np.abs(V_new - V)) < theta:
            break
            
        V = V_new
        
    return V

# policy evaluation for iteration sync
def policy_evaluation_for_sync(p, r, policy, gamma=0.9, theta=1e-6):
    """
    Policy evaluation using for loops
    
    Args:
        p: transition probability matrix (S x A x S)
        r: reward matrix (S x A)
        policy: policy matrix (S x A)
        gamma: discount factor
        theta: threshold
        
    Returns:
        V: state-value function (S)
    """
    n_states = p.shape[0]
    n_actions = p.shape[1]
    
    # Initialize value function
    V = np.zeros(n_states)
    
    while True:
        delta = 0
        V_new = np.zeros(n_states)
        
        # For each state
        for s in range(n_states):
            v = V[s]
            total = 0
            
            # For each action
            for a in range(n_actions):
                # Calculate expected reward
                reward = r[s, a]
                
                # Calculate expected next state value
                next_state_value = 0
                for s_prime in range(n_states):
                    next_state_value+= p[s, a, s_prime] * V[s_prime]
                
                # Add to total with policy probability
                total += policy[s, a] * (reward + gamma * next_state_value)
            
            V_new[s] = total
            delta = max(delta, abs(v - V_new[s]))
        
        V = V_new
        
        # convergence
        if delta < theta:
            break
            
    return V

# policy evaluation for iteration async
def policy_evaluation_for_async(p, r, policy, gamma=0.9, theta=1e-6):
    """
    Policy evaluation using for loops async
    
    Args:
        p: transition probability matrix (S x A x S)
        r: reward matrix (S x A)
        policy: policy matrix (S x A)
        gamma: discount factor
        theta: threshold
        
    Returns:
        V: state-value function (S)
    """
    n_states = p.shape[0]
    n_actions = p.shape[1]

    V = np.zeros(n_states)
    while True:
        delta=0

        for s in range(n_states):
            v = V[s]
            total = 0

            for a in range(n_actions):
                reward = r[s,a]

                next_state_value = 0
                for s_prime in range(n_states):
                    next_state_value += p[s,a,s_prime] * V[s_prime]
                
                total += policy[s,a] * (reward + gamma * next_state_value)

            V[s] = total
            delta = max(delta,abs(v-V[s]))
        
        if delta < theta:
            break 
    return V

# %% [markdown]
# # Policy Improvement

# %%
# policy improvement matrix
def policy_improvement_matrix(p, r, V, gamma=0.9):
    """
    policy improvement 
    
    Args:
        p: transition probability matrix (S x A x S)
        r: reward matrix (S x A)
        V: current value function (S)
        gamma: discount factor
        
    Returns:
        new_policy: improved policy matrix (S x A)
    """
    # Q(s,a) = R(s,a) + gamma * sum_s' P(s'|s,a) * V(s')
    Q = r + gamma * np.sum(p * V[np.newaxis, np.newaxis, :], axis=2)

    new_policy = np.zeros_like(Q)
    best_actions = np.argmax(Q, axis=1)
    new_policy[np.arange(len(Q)), best_actions] = 1
    
    return new_policy

# %% [markdown]
# ## policy iteration, value iteration

# %%
# policy iteration
def policy_iteration_matrix(p, r, policy, gamma=0.9, theta=1e-6):
    """
    policy iteration 
    
    Args:
        p: transition probability matrix (S x A x S)
        r: reward matrix (S x A)
        gamma: discount factor
        theta: threshold
        
    Returns:
        new_policy: improved policy matrix (S x A)
    """
    while True:
        V = policy_evaluation_matrix(p, r, policy, gamma, theta)
        new_policy = policy_improvement_matrix(p, r, V, gamma)
        
        if new_policy.all() == policy.all():
            break
        
        policy = new_policy
        
    return policy, V

# value iteration
def value_iteration_matrix(p, r, gamma=0.9, theta=1e-6):
    """
    Args:
        p: transition probability matrix (S x A x S)
        r: reward matrix (S x A)
        gamma: discount factor
        theta: convergence threshold
        
    Returns:
        V: optimal state-value function (S)
        policy: optimal policy (S x A)
    """
    n_states = p.shape[0]
    n_actions = p.shape[1]
    
    # Initialize value function
    V = np.zeros(n_states)
    
    while True:
        # Q-values for all state-action pairs
        ## Q(s,a) = R(s,a) + gamma * sum_s' P(s'|s,a) * V(s')
        Q = r + gamma * np.sum(p * V[np.newaxis, np.newaxis, :], axis=2)
        
        # new value function 
        V_new = np.max(Q, axis=1)
        
        # convergence
        if np.max(np.abs(V_new - V)) < theta:
            break
            
        V = V_new
    
    policy = np.zeros((n_states, n_actions))
    best_actions = np.argmax(Q, axis=1)
    policy[np.arange(n_states), best_actions] = 1
    
    return policy, V

# %%
# state, action, gamma
s= 10
a = 5
gamma = 0.9

# transition prob, reward matrix
P,R = env(s,a)

# random policy
policy = random_policy(s,a)

# %%
for s in range(1,1000):
    for a in range(1,10):
        P,R = env(s,a)
        policy = random_policy(s,a)
        execution_time = []
        start_time = time.time()
        linear_equation(P,R,policy,gamma)
        end_time = time.time()
        linear_equation_time = end_time - start_time
        execution_time.append(linear_equation_time)

        start_time = time.time()
        policy, V = policy_iteration_matrix(P,R,policy)
        end_time = time.time()
        policy_iteration_time = end_time - start_time
        execution_time.append(policy_iteration_time)
        
        start_time = time.time()
        policy, V = value_iteration_matrix(P,R)
        end_time = time.time()
        value_iteration_time = end_time - start_time
        execution_time.append(value_iteration_time)

        min_time = min(execution_time)
        if min_time == linear_equation_time:
            print(f'state_dim: {s}, action_dim: {a}, fast algorithm: linear equation')
        elif min_time == policy_iteration_time:
            print(f'state_dim: {s}, action_dim: {a}, fast algorithm: policy iteration')
        else:
            print(f'state_dim: {s}, action_dim: {a}, fast algorithm: value iteration')
# Out:
# state_dim: 1, action_dim: 1, fast algorithm: linear equation
# state_dim: 1, action_dim: 2, fast algorithm: linear equation
# state_dim: 1, action_dim: 3, fast algorithm: linear equation
# state_dim: 1, action_dim: 4, fast algorithm: linear equation
# state_dim: 1, action_dim: 5, fast algorithm: linear equation
# state_dim: 1, action_dim: 6, fast algorithm: linear equation
# state_dim: 1, action_dim: 7, fast algorithm: linear equation
# state_dim: 1, action_dim: 8, fast algorithm: linear equation
# state_dim: 1, action_dim: 9, fast algorithm: linear equation
# state_dim: 2, action_dim: 1, fast algorithm: linear equation
# state_dim: 2, action_dim: 2, fast algorithm: linear equation
# state_dim: 2, action_dim: 3, fast algorithm: linear equation
# state_dim: 2, action_dim: 4, fast algorithm: linear equation
# state_dim: 2, action_dim: 5, fast algorithm: linear equation
# state_dim: 2, action_dim: 6, fast algorithm: linear equation
# state_dim: 2, action_dim: 7, fast algorithm: linear equation
# state_dim: 2, action_dim: 8, fast algorithm: linear equation
# state_dim: 2, action_dim: 9, fast algorithm: linear equation
# state_dim: 3, action_dim: 1, fast algorithm: policy iteration
# state_dim: 3, action_dim: 2, fast algorithm: linear equation
# state_dim: 3, action_dim: 3, fast algorithm: linear equation
# state_dim: 3, action_dim: 4, fast algorithm: linear equation
# state_dim: 3, action_dim: 5, fast algorithm: linear equation
# state_dim: 3, action_dim: 6, fast algorithm: linear equation
# state_dim: 3, action_dim: 7, fast algorithm: linear equation
# state_dim: 3, action_dim: 8, fast algorithm: linear equation
# state_dim: 3, action_dim: 9, fast algorithm: linear equation
# state_dim: 4, action_dim: 1, fast algorithm: linear equation
# state_dim: 4, action_dim: 2, fast algorithm: linear equation
# state_dim: 4, action_dim: 3, fast algorithm: linear equation
# state_dim: 4, action_dim: 4, fast algorithm: linear equation
# state_dim: 4, action_dim: 5, fast algorithm: linear equation
# state_dim: 4, action_dim: 6, fast algorithm: linear equation
# state_dim: 4, action_dim: 7, fast algorithm: linear equation
# state_dim: 4, action_dim: 8, fast algorithm: linear equation
# state_dim: 4, action_dim: 9, fast algorithm: linear equation
# state_dim: 5, action_dim: 1, fast algorithm: linear equation
# state_dim: 5, action_dim: 2, fast algorithm: linear equation
# state_dim: 5, action_dim: 3, fast algorithm: linear equation
# state_dim: 5, action_dim: 4, fast algorithm: linear equation
# state_dim: 5, action_dim: 5, fast algorithm: linear equation
# state_dim: 5, action_dim: 6, fast algorithm: linear equation
# state_dim: 5, action_dim: 7, fast algorithm: linear equation
# state_dim: 5, action_dim: 8, fast algorithm: linear equation
# state_dim: 5, action_dim: 9, fast algorithm: linear equation
# state_dim: 6, action_dim: 1, fast algorithm: linear equation
# state_dim: 6, action_dim: 2, fast algorithm: linear equation
# state_dim: 6, action_dim: 3, fast algorithm: linear equation
# state_dim: 6, action_dim: 4, fast algorithm: linear equation
# state_dim: 6, action_dim: 5, fast algorithm: linear equation
# state_dim: 6, action_dim: 6, fast algorithm: linear equation
# state_dim: 6, action_dim: 7, fast algorithm: linear equation
# state_dim: 6, action_dim: 8, fast algorithm: linear equation
# state_dim: 6, action_dim: 9, fast algorithm: linear equation
# state_dim: 7, action_dim: 1, fast algorithm: linear equation
# state_dim: 7, action_dim: 2, fast algorithm: linear equation
# state_dim: 7, action_dim: 3, fast algorithm: linear equation
# state_dim: 7, action_dim: 4, fast algorithm: linear equation
# state_dim: 7, action_dim: 5, fast algorithm: linear equation
# state_dim: 7, action_dim: 6, fast algorithm: linear equation
# state_dim: 7, action_dim: 7, fast algorithm: linear equation
# state_dim: 7, action_dim: 8, fast algorithm: linear equation
# state_dim: 7, action_dim: 9, fast algorithm: linear equation
# state_dim: 8, action_dim: 1, fast algorithm: linear equation
# state_dim: 8, action_dim: 2, fast algorithm: linear equation
# state_dim: 8, action_dim: 3, fast algorithm: linear equation
# state_dim: 8, action_dim: 4, fast algorithm: linear equation
# state_dim: 8, action_dim: 5, fast algorithm: linear equation
# state_dim: 8, action_dim: 6, fast algorithm: linear equation
# state_dim: 8, action_dim: 7, fast algorithm: linear equation
# state_dim: 8, action_dim: 8, fast algorithm: linear equation
# state_dim: 8, action_dim: 9, fast algorithm: linear equation
# state_dim: 9, action_dim: 1, fast algorithm: linear equation
# state_dim: 9, action_dim: 2, fast algorithm: linear equation
# state_dim: 9, action_dim: 3, fast algorithm: linear equation
# state_dim: 9, action_dim: 4, fast algorithm: linear equation
# state_dim: 9, action_dim: 5, fast algorithm: linear equation
# state_dim: 9, action_dim: 6, fast algorithm: policy iteration
# state_dim: 9, action_dim: 7, fast algorithm: linear equation
# state_dim: 9, action_dim: 8, fast algorithm: linear equation
# state_dim: 9, action_dim: 9, fast algorithm: linear equation
# state_dim: 10, action_dim: 1, fast algorithm: linear equation
# state_dim: 10, action_dim: 2, fast algorithm: linear equation
# state_dim: 10, action_dim: 3, fast algorithm: linear equation
# state_dim: 10, action_dim: 4, fast algorithm: linear equation
# state_dim: 10, action_dim: 5, fast algorithm: linear equation
# state_dim: 10, action_dim: 6, fast algorithm: linear equation
# state_dim: 10, action_dim: 7, fast algorithm: linear equation
# state_dim: 10, action_dim: 8, fast algorithm: linear equation
# state_dim: 10, action_dim: 9, fast algorithm: linear equation
# state_dim: 11, action_dim: 1, fast algorithm: linear equation
# state_dim: 11, action_dim: 2, fast algorithm: linear equation
# state_dim: 11, action_dim: 3, fast algorithm: linear equation
# state_dim: 11, action_dim: 4, fast algorithm: linear equation
# state_dim: 11, action_dim: 5, fast algorithm: linear equation
# state_dim: 11, action_dim: 6, fast algorithm: linear equation
# state_dim: 11, action_dim: 7, fast algorithm: linear equation
# state_dim: 11, action_dim: 8, fast algorithm: linear equation
# state_dim: 11, action_dim: 9, fast algorithm: linear equation
# state_dim: 12, action_dim: 1, fast algorithm: linear equation
# state_dim: 12, action_dim: 2, fast algorithm: linear equation
# state_dim: 12, action_dim: 3, fast algorithm: linear equation
# state_dim: 12, action_dim: 4, fast algorithm: linear equation
# state_dim: 12, action_dim: 5, fast algorithm: linear equation
# state_dim: 12, action_dim: 6, fast algorithm: linear equation
# state_dim: 12, action_dim: 7, fast algorithm: linear equation
# state_dim: 12, action_dim: 8, fast algorithm: linear equation
# state_dim: 12, action_dim: 9, fast algorithm: linear equation
# state_dim: 13, action_dim: 1, fast algorithm: linear equation
# state_dim: 13, action_dim: 2, fast algorithm: linear equation
# state_dim: 13, action_dim: 3, fast algorithm: linear equation
# state_dim: 13, action_dim: 4, fast algorithm: linear equation
# state_dim: 13, action_dim: 5, fast algorithm: linear equation
# state_dim: 13, action_dim: 6, fast algorithm: linear equation
# state_dim: 13, action_dim: 7, fast algorithm: linear equation
# state_dim: 13, action_dim: 8, fast algorithm: linear equation
# state_dim: 13, action_dim: 9, fast algorithm: linear equation
# state_dim: 14, action_dim: 1, fast algorithm: linear equation
# state_dim: 14, action_dim: 2, fast algorithm: linear equation
# state_dim: 14, action_dim: 3, fast algorithm: linear equation
# state_dim: 14, action_dim: 4, fast algorithm: linear equation
# state_dim: 14, action_dim: 5, fast algorithm: linear equation
# state_dim: 14, action_dim: 6, fast algorithm: linear equation
# state_dim: 14, action_dim: 7, fast algorithm: linear equation
# state_dim: 14, action_dim: 8, fast algorithm: linear equation
# state_dim: 14, action_dim: 9, fast algorithm: linear equation
# state_dim: 15, action_dim: 1, fast algorithm: linear equation
# state_dim: 15, action_dim: 2, fast algorithm: linear equation
# state_dim: 15, action_dim: 3, fast algorithm: linear equation
# state_dim: 15, action_dim: 4, fast algorithm: linear equation
# state_dim: 15, action_dim: 5, fast algorithm: linear equation
# state_dim: 15, action_dim: 6, fast algorithm: linear equation
# state_dim: 15, action_dim: 7, fast algorithm: linear equation
# state_dim: 15, action_dim: 8, fast algorithm: linear equation
# state_dim: 15, action_dim: 9, fast algorithm: linear equation
# state_dim: 16, action_dim: 1, fast algorithm: linear equation
# state_dim: 16, action_dim: 2, fast algorithm: linear equation
# state_dim: 16, action_dim: 3, fast algorithm: linear equation
# state_dim: 16, action_dim: 4, fast algorithm: linear equation
# state_dim: 16, action_dim: 5, fast algorithm: linear equation
# state_dim: 16, action_dim: 6, fast algorithm: linear equation
# state_dim: 16, action_dim: 7, fast algorithm: linear equation
# state_dim: 16, action_dim: 8, fast algorithm: linear equation
# state_dim: 16, action_dim: 9, fast algorithm: linear equation
# state_dim: 17, action_dim: 1, fast algorithm: linear equation
# state_dim: 17, action_dim: 2, fast algorithm: linear equation
# state_dim: 17, action_dim: 3, fast algorithm: linear equation
# state_dim: 17, action_dim: 4, fast algorithm: linear equation
# state_dim: 17, action_dim: 5, fast algorithm: linear equation
# state_dim: 17, action_dim: 6, fast algorithm: linear equation
# state_dim: 17, action_dim: 7, fast algorithm: linear equation
# state_dim: 17, action_dim: 8, fast algorithm: linear equation
# state_dim: 17, action_dim: 9, fast algorithm: linear equation
# state_dim: 18, action_dim: 1, fast algorithm: linear equation
# state_dim: 18, action_dim: 2, fast algorithm: linear equation
# state_dim: 18, action_dim: 3, fast algorithm: linear equation
# state_dim: 18, action_dim: 4, fast algorithm: linear equation
# state_dim: 18, action_dim: 5, fast algorithm: linear equation
# state_dim: 18, action_dim: 6, fast algorithm: linear equation
# state_dim: 18, action_dim: 7, fast algorithm: linear equation
# state_dim: 18, action_dim: 8, fast algorithm: linear equation
# state_dim: 18, action_dim: 9, fast algorithm: linear equation
# state_dim: 19, action_dim: 1, fast algorithm: linear equation
# state_dim: 19, action_dim: 2, fast algorithm: linear equation
# state_dim: 19, action_dim: 3, fast algorithm: linear equation
# state_dim: 19, action_dim: 4, fast algorithm: linear equation
# state_dim: 19, action_dim: 5, fast algorithm: linear equation
# state_dim: 19, action_dim: 6, fast algorithm: linear equation
# state_dim: 19, action_dim: 7, fast algorithm: linear equation
# state_dim: 19, action_dim: 8, fast algorithm: linear equation
# state_dim: 19, action_dim: 9, fast algorithm: linear equation
# state_dim: 20, action_dim: 1, fast algorithm: linear equation
# state_dim: 20, action_dim: 2, fast algorithm: linear equation
# state_dim: 20, action_dim: 3, fast algorithm: linear equation
# state_dim: 20, action_dim: 4, fast algorithm: linear equation
# state_dim: 20, action_dim: 5, fast algorithm: linear equation
# state_dim: 20, action_dim: 6, fast algorithm: linear equation
# state_dim: 20, action_dim: 7, fast algorithm: linear equation
# state_dim: 20, action_dim: 8, fast algorithm: linear equation
# state_dim: 20, action_dim: 9, fast algorithm: linear equation
# state_dim: 21, action_dim: 1, fast algorithm: linear equation
# state_dim: 21, action_dim: 2, fast algorithm: linear equation
# state_dim: 21, action_dim: 3, fast algorithm: linear equation
# state_dim: 21, action_dim: 4, fast algorithm: linear equation
# state_dim: 21, action_dim: 5, fast algorithm: linear equation
# state_dim: 21, action_dim: 6, fast algorithm: linear equation
# state_dim: 21, action_dim: 7, fast algorithm: linear equation
# state_dim: 21, action_dim: 8, fast algorithm: linear equation
# state_dim: 21, action_dim: 9, fast algorithm: linear equation
# state_dim: 22, action_dim: 1, fast algorithm: linear equation
# state_dim: 22, action_dim: 2, fast algorithm: linear equation
# state_dim: 22, action_dim: 3, fast algorithm: linear equation
# state_dim: 22, action_dim: 4, fast algorithm: linear equation
# state_dim: 22, action_dim: 5, fast algorithm: linear equation
# state_dim: 22, action_dim: 6, fast algorithm: linear equation
# state_dim: 22, action_dim: 7, fast algorithm: linear equation
# state_dim: 22, action_dim: 8, fast algorithm: linear equation
# state_dim: 22, action_dim: 9, fast algorithm: linear equation
# state_dim: 23, action_dim: 1, fast algorithm: linear equation
# state_dim: 23, action_dim: 2, fast algorithm: linear equation
# state_dim: 23, action_dim: 3, fast algorithm: linear equation
# state_dim: 23, action_dim: 4, fast algorithm: linear equation
# state_dim: 23, action_dim: 5, fast algorithm: linear equation
# state_dim: 23, action_dim: 6, fast algorithm: policy iteration
# state_dim: 23, action_dim: 7, fast algorithm: linear equation
# state_dim: 23, action_dim: 8, fast algorithm: linear equation
# state_dim: 23, action_dim: 9, fast algorithm: linear equation
# state_dim: 24, action_dim: 1, fast algorithm: linear equation
# state_dim: 24, action_dim: 2, fast algorithm: linear equation
# state_dim: 24, action_dim: 3, fast algorithm: linear equation
# state_dim: 24, action_dim: 4, fast algorithm: linear equation
# state_dim: 24, action_dim: 5, fast algorithm: linear equation
# state_dim: 24, action_dim: 6, fast algorithm: linear equation
# state_dim: 24, action_dim: 7, fast algorithm: linear equation
# state_dim: 24, action_dim: 8, fast algorithm: linear equation
# state_dim: 24, action_dim: 9, fast algorithm: linear equation
# state_dim: 25, action_dim: 1, fast algorithm: linear equation
# state_dim: 25, action_dim: 2, fast algorithm: linear equation
# state_dim: 25, action_dim: 3, fast algorithm: linear equation
# state_dim: 25, action_dim: 4, fast algorithm: linear equation
# state_dim: 25, action_dim: 5, fast algorithm: linear equation
# state_dim: 25, action_dim: 6, fast algorithm: linear equation
# state_dim: 25, action_dim: 7, fast algorithm: policy iteration
# state_dim: 25, action_dim: 8, fast algorithm: linear equation
# state_dim: 25, action_dim: 9, fast algorithm: linear equation
# state_dim: 26, action_dim: 1, fast algorithm: linear equation
# state_dim: 26, action_dim: 2, fast algorithm: linear equation
# state_dim: 26, action_dim: 3, fast algorithm: linear equation
# state_dim: 26, action_dim: 4, fast algorithm: linear equation
# state_dim: 26, action_dim: 5, fast algorithm: linear equation
# state_dim: 26, action_dim: 6, fast algorithm: linear equation
# state_dim: 26, action_dim: 7, fast algorithm: linear equation
# state_dim: 26, action_dim: 8, fast algorithm: linear equation
# state_dim: 26, action_dim: 9, fast algorithm: linear equation
# state_dim: 27, action_dim: 1, fast algorithm: linear equation
# state_dim: 27, action_dim: 2, fast algorithm: linear equation
# state_dim: 27, action_dim: 3, fast algorithm: linear equation
# state_dim: 27, action_dim: 4, fast algorithm: linear equation
# state_dim: 27, action_dim: 5, fast algorithm: linear equation
# state_dim: 27, action_dim: 6, fast algorithm: linear equation
# state_dim: 27, action_dim: 7, fast algorithm: linear equation
# state_dim: 27, action_dim: 8, fast algorithm: linear equation
# state_dim: 27, action_dim: 9, fast algorithm: linear equation
# state_dim: 28, action_dim: 1, fast algorithm: linear equation
# state_dim: 28, action_dim: 2, fast algorithm: linear equation
# state_dim: 28, action_dim: 3, fast algorithm: linear equation
# state_dim: 28, action_dim: 4, fast algorithm: linear equation
# state_dim: 28, action_dim: 5, fast algorithm: linear equation
# state_dim: 28, action_dim: 6, fast algorithm: linear equation
# state_dim: 28, action_dim: 7, fast algorithm: linear equation
# state_dim: 28, action_dim: 8, fast algorithm: linear equation
# state_dim: 28, action_dim: 9, fast algorithm: linear equation
# state_dim: 29, action_dim: 1, fast algorithm: linear equation
# state_dim: 29, action_dim: 2, fast algorithm: linear equation
# state_dim: 29, action_dim: 3, fast algorithm: linear equation
# state_dim: 29, action_dim: 4, fast algorithm: linear equation
# state_dim: 29, action_dim: 5, fast algorithm: linear equation
# state_dim: 29, action_dim: 6, fast algorithm: linear equation
# state_dim: 29, action_dim: 7, fast algorithm: linear equation
# state_dim: 29, action_dim: 8, fast algorithm: linear equation
# state_dim: 29, action_dim: 9, fast algorithm: linear equation
# state_dim: 30, action_dim: 1, fast algorithm: linear equation
# state_dim: 30, action_dim: 2, fast algorithm: linear equation
# state_dim: 30, action_dim: 3, fast algorithm: linear equation
# state_dim: 30, action_dim: 4, fast algorithm: linear equation
# state_dim: 30, action_dim: 5, fast algorithm: linear equation
# state_dim: 30, action_dim: 6, fast algorithm: linear equation
# state_dim: 30, action_dim: 7, fast algorithm: linear equation
# state_dim: 30, action_dim: 8, fast algorithm: linear equation
# state_dim: 30, action_dim: 9, fast algorithm: linear equation
# state_dim: 31, action_dim: 1, fast algorithm: linear equation
# state_dim: 31, action_dim: 2, fast algorithm: linear equation
# state_dim: 31, action_dim: 3, fast algorithm: linear equation
# state_dim: 31, action_dim: 4, fast algorithm: linear equation
# state_dim: 31, action_dim: 5, fast algorithm: linear equation
# state_dim: 31, action_dim: 6, fast algorithm: linear equation
# state_dim: 31, action_dim: 7, fast algorithm: linear equation
# state_dim: 31, action_dim: 8, fast algorithm: linear equation
# state_dim: 31, action_dim: 9, fast algorithm: linear equation
# state_dim: 32, action_dim: 1, fast algorithm: policy iteration
# state_dim: 32, action_dim: 2, fast algorithm: linear equation
# state_dim: 32, action_dim: 3, fast algorithm: linear equation
# state_dim: 32, action_dim: 4, fast algorithm: linear equation
# state_dim: 32, action_dim: 5, fast algorithm: linear equation
# state_dim: 32, action_dim: 6, fast algorithm: linear equation
# state_dim: 32, action_dim: 7, fast algorithm: linear equation
# state_dim: 32, action_dim: 8, fast algorithm: linear equation
# state_dim: 32, action_dim: 9, fast algorithm: linear equation
# state_dim: 33, action_dim: 1, fast algorithm: policy iteration
# state_dim: 33, action_dim: 2, fast algorithm: linear equation
# state_dim: 33, action_dim: 3, fast algorithm: linear equation
# state_dim: 33, action_dim: 4, fast algorithm: linear equation
# state_dim: 33, action_dim: 5, fast algorithm: linear equation
# state_dim: 33, action_dim: 6, fast algorithm: linear equation
# state_dim: 33, action_dim: 7, fast algorithm: linear equation
# state_dim: 33, action_dim: 8, fast algorithm: linear equation
# state_dim: 33, action_dim: 9, fast algorithm: linear equation
# state_dim: 34, action_dim: 1, fast algorithm: policy iteration
# state_dim: 34, action_dim: 2, fast algorithm: linear equation
# state_dim: 34, action_dim: 3, fast algorithm: linear equation
# state_dim: 34, action_dim: 4, fast algorithm: linear equation
# state_dim: 34, action_dim: 5, fast algorithm: linear equation
# state_dim: 34, action_dim: 6, fast algorithm: linear equation
# state_dim: 34, action_dim: 7, fast algorithm: linear equation
# state_dim: 34, action_dim: 8, fast algorithm: linear equation
# state_dim: 34, action_dim: 9, fast algorithm: policy iteration
# state_dim: 35, action_dim: 1, fast algorithm: linear equation
# state_dim: 35, action_dim: 2, fast algorithm: linear equation
# state_dim: 35, action_dim: 3, fast algorithm: linear equation
# state_dim: 35, action_dim: 4, fast algorithm: linear equation
# state_dim: 35, action_dim: 5, fast algorithm: linear equation
# state_dim: 35, action_dim: 6, fast algorithm: linear equation
# state_dim: 35, action_dim: 7, fast algorithm: linear equation
# state_dim: 35, action_dim: 8, fast algorithm: linear equation
# state_dim: 35, action_dim: 9, fast algorithm: linear equation
# state_dim: 36, action_dim: 1, fast algorithm: policy iteration
# state_dim: 36, action_dim: 2, fast algorithm: linear equation
# state_dim: 36, action_dim: 3, fast algorithm: linear equation
# state_dim: 36, action_dim: 4, fast algorithm: linear equation
# state_dim: 36, action_dim: 5, fast algorithm: linear equation
# state_dim: 36, action_dim: 6, fast algorithm: linear equation
# state_dim: 36, action_dim: 7, fast algorithm: linear equation
# state_dim: 36, action_dim: 8, fast algorithm: linear equation
# state_dim: 36, action_dim: 9, fast algorithm: linear equation
# state_dim: 37, action_dim: 1, fast algorithm: linear equation
# state_dim: 37, action_dim: 2, fast algorithm: linear equation
# state_dim: 37, action_dim: 3, fast algorithm: linear equation
# state_dim: 37, action_dim: 4, fast algorithm: linear equation
# state_dim: 37, action_dim: 5, fast algorithm: linear equation
# state_dim: 37, action_dim: 6, fast algorithm: linear equation
# state_dim: 37, action_dim: 7, fast algorithm: linear equation
# state_dim: 37, action_dim: 8, fast algorithm: linear equation
# state_dim: 37, action_dim: 9, fast algorithm: linear equation
# state_dim: 38, action_dim: 1, fast algorithm: policy iteration
# state_dim: 38, action_dim: 2, fast algorithm: linear equation
# state_dim: 38, action_dim: 3, fast algorithm: linear equation
# state_dim: 38, action_dim: 4, fast algorithm: linear equation
# state_dim: 38, action_dim: 5, fast algorithm: linear equation
# state_dim: 38, action_dim: 6, fast algorithm: linear equation
# state_dim: 38, action_dim: 7, fast algorithm: policy iteration
# state_dim: 38, action_dim: 8, fast algorithm: linear equation
# state_dim: 38, action_dim: 9, fast algorithm: linear equation
# state_dim: 39, action_dim: 1, fast algorithm: policy iteration
# state_dim: 39, action_dim: 2, fast algorithm: linear equation
# state_dim: 39, action_dim: 3, fast algorithm: linear equation
# state_dim: 39, action_dim: 4, fast algorithm: linear equation
# state_dim: 39, action_dim: 5, fast algorithm: linear equation
# state_dim: 39, action_dim: 6, fast algorithm: linear equation
# state_dim: 39, action_dim: 7, fast algorithm: linear equation
# state_dim: 39, action_dim: 8, fast algorithm: linear equation
# state_dim: 39, action_dim: 9, fast algorithm: linear equation
# state_dim: 40, action_dim: 1, fast algorithm: linear equation
# state_dim: 40, action_dim: 2, fast algorithm: linear equation
# state_dim: 40, action_dim: 3, fast algorithm: linear equation
# state_dim: 40, action_dim: 4, fast algorithm: linear equation
# state_dim: 40, action_dim: 5, fast algorithm: linear equation
# state_dim: 40, action_dim: 6, fast algorithm: linear equation
# state_dim: 40, action_dim: 7, fast algorithm: linear equation
# state_dim: 40, action_dim: 8, fast algorithm: linear equation
# state_dim: 40, action_dim: 9, fast algorithm: linear equation
# state_dim: 41, action_dim: 1, fast algorithm: policy iteration
# state_dim: 41, action_dim: 2, fast algorithm: linear equation
# state_dim: 41, action_dim: 3, fast algorithm: linear equation
# state_dim: 41, action_dim: 4, fast algorithm: linear equation
# state_dim: 41, action_dim: 5, fast algorithm: linear equation
# state_dim: 41, action_dim: 6, fast algorithm: linear equation
# state_dim: 41, action_dim: 7, fast algorithm: linear equation
# state_dim: 41, action_dim: 8, fast algorithm: linear equation
# state_dim: 41, action_dim: 9, fast algorithm: linear equation
# state_dim: 42, action_dim: 1, fast algorithm: linear equation
# state_dim: 42, action_dim: 2, fast algorithm: linear equation
# state_dim: 42, action_dim: 3, fast algorithm: linear equation
# state_dim: 42, action_dim: 4, fast algorithm: linear equation
# state_dim: 42, action_dim: 5, fast algorithm: linear equation
# state_dim: 42, action_dim: 6, fast algorithm: linear equation
# state_dim: 42, action_dim: 7, fast algorithm: linear equation
# state_dim: 42, action_dim: 8, fast algorithm: linear equation
# state_dim: 42, action_dim: 9, fast algorithm: linear equation
# state_dim: 43, action_dim: 1, fast algorithm: policy iteration
# state_dim: 43, action_dim: 2, fast algorithm: linear equation
# state_dim: 43, action_dim: 3, fast algorithm: linear equation
# state_dim: 43, action_dim: 4, fast algorithm: linear equation
# state_dim: 43, action_dim: 5, fast algorithm: linear equation
# state_dim: 43, action_dim: 6, fast algorithm: policy iteration
# state_dim: 43, action_dim: 7, fast algorithm: linear equation
# state_dim: 43, action_dim: 8, fast algorithm: linear equation
# state_dim: 43, action_dim: 9, fast algorithm: linear equation
# state_dim: 44, action_dim: 1, fast algorithm: policy iteration
# state_dim: 44, action_dim: 2, fast algorithm: linear equation
# state_dim: 44, action_dim: 3, fast algorithm: linear equation
# state_dim: 44, action_dim: 4, fast algorithm: linear equation
# state_dim: 44, action_dim: 5, fast algorithm: linear equation
# state_dim: 44, action_dim: 6, fast algorithm: linear equation
# state_dim: 44, action_dim: 7, fast algorithm: linear equation
# state_dim: 44, action_dim: 8, fast algorithm: linear equation
# state_dim: 44, action_dim: 9, fast algorithm: linear equation
# state_dim: 45, action_dim: 1, fast algorithm: policy iteration
# state_dim: 45, action_dim: 2, fast algorithm: linear equation
# state_dim: 45, action_dim: 3, fast algorithm: linear equation
# state_dim: 45, action_dim: 4, fast algorithm: linear equation
# state_dim: 45, action_dim: 5, fast algorithm: linear equation
# state_dim: 45, action_dim: 6, fast algorithm: linear equation
# state_dim: 45, action_dim: 7, fast algorithm: linear equation
# state_dim: 45, action_dim: 8, fast algorithm: linear equation
# state_dim: 45, action_dim: 9, fast algorithm: linear equation
# state_dim: 46, action_dim: 1, fast algorithm: policy iteration
# state_dim: 46, action_dim: 2, fast algorithm: linear equation
# state_dim: 46, action_dim: 3, fast algorithm: linear equation
# state_dim: 46, action_dim: 4, fast algorithm: linear equation
# state_dim: 46, action_dim: 5, fast algorithm: linear equation
# state_dim: 46, action_dim: 6, fast algorithm: linear equation
# state_dim: 46, action_dim: 7, fast algorithm: linear equation
# state_dim: 46, action_dim: 8, fast algorithm: linear equation
# state_dim: 46, action_dim: 9, fast algorithm: linear equation
# state_dim: 47, action_dim: 1, fast algorithm: policy iteration
# state_dim: 47, action_dim: 2, fast algorithm: linear equation
# state_dim: 47, action_dim: 3, fast algorithm: linear equation
# state_dim: 47, action_dim: 4, fast algorithm: linear equation
# state_dim: 47, action_dim: 5, fast algorithm: linear equation
# state_dim: 47, action_dim: 6, fast algorithm: linear equation
# state_dim: 47, action_dim: 7, fast algorithm: linear equation
# state_dim: 47, action_dim: 8, fast algorithm: linear equation
# state_dim: 47, action_dim: 9, fast algorithm: linear equation
# state_dim: 48, action_dim: 1, fast algorithm: policy iteration
# state_dim: 48, action_dim: 2, fast algorithm: linear equation
# state_dim: 48, action_dim: 3, fast algorithm: linear equation
# state_dim: 48, action_dim: 4, fast algorithm: linear equation
# state_dim: 48, action_dim: 5, fast algorithm: linear equation
# state_dim: 48, action_dim: 6, fast algorithm: linear equation
# state_dim: 48, action_dim: 7, fast algorithm: linear equation
# state_dim: 48, action_dim: 8, fast algorithm: linear equation
# state_dim: 48, action_dim: 9, fast algorithm: linear equation
# state_dim: 49, action_dim: 1, fast algorithm: policy iteration
# state_dim: 49, action_dim: 2, fast algorithm: linear equation
# state_dim: 49, action_dim: 3, fast algorithm: linear equation
# state_dim: 49, action_dim: 4, fast algorithm: linear equation
# state_dim: 49, action_dim: 5, fast algorithm: linear equation
# state_dim: 49, action_dim: 6, fast algorithm: linear equation
# state_dim: 49, action_dim: 7, fast algorithm: linear equation
# state_dim: 49, action_dim: 8, fast algorithm: policy iteration
# state_dim: 49, action_dim: 9, fast algorithm: linear equation
# state_dim: 50, action_dim: 1, fast algorithm: policy iteration
# state_dim: 50, action_dim: 2, fast algorithm: linear equation
# state_dim: 50, action_dim: 3, fast algorithm: linear equation
# state_dim: 50, action_dim: 4, fast algorithm: linear equation
# state_dim: 50, action_dim: 5, fast algorithm: linear equation
# state_dim: 50, action_dim: 6, fast algorithm: linear equation
# state_dim: 50, action_dim: 7, fast algorithm: linear equation
# state_dim: 50, action_dim: 8, fast algorithm: linear equation
# state_dim: 50, action_dim: 9, fast algorithm: linear equation
# state_dim: 51, action_dim: 1, fast algorithm: policy iteration
# state_dim: 51, action_dim: 2, fast algorithm: linear equation
# state_dim: 51, action_dim: 3, fast algorithm: linear equation
# state_dim: 51, action_dim: 4, fast algorithm: linear equation
# state_dim: 51, action_dim: 5, fast algorithm: linear equation
# state_dim: 51, action_dim: 6, fast algorithm: linear equation
# state_dim: 51, action_dim: 7, fast algorithm: linear equation
# state_dim: 51, action_dim: 8, fast algorithm: linear equation
# state_dim: 51, action_dim: 9, fast algorithm: policy iteration
# state_dim: 52, action_dim: 1, fast algorithm: policy iteration
# state_dim: 52, action_dim: 2, fast algorithm: linear equation
# state_dim: 52, action_dim: 3, fast algorithm: linear equation
# state_dim: 52, action_dim: 4, fast algorithm: linear equation
# state_dim: 52, action_dim: 5, fast algorithm: linear equation
# state_dim: 52, action_dim: 6, fast algorithm: linear equation
# state_dim: 52, action_dim: 7, fast algorithm: linear equation
# state_dim: 52, action_dim: 8, fast algorithm: linear equation
# state_dim: 52, action_dim: 9, fast algorithm: policy iteration
# state_dim: 53, action_dim: 1, fast algorithm: policy iteration
# state_dim: 53, action_dim: 2, fast algorithm: linear equation
# state_dim: 53, action_dim: 3, fast algorithm: linear equation
# state_dim: 53, action_dim: 4, fast algorithm: linear equation
# state_dim: 53, action_dim: 5, fast algorithm: linear equation
# state_dim: 53, action_dim: 6, fast algorithm: linear equation
# state_dim: 53, action_dim: 7, fast algorithm: linear equation
# state_dim: 53, action_dim: 8, fast algorithm: linear equation
# state_dim: 53, action_dim: 9, fast algorithm: linear equation
# state_dim: 54, action_dim: 1, fast algorithm: policy iteration
# state_dim: 54, action_dim: 2, fast algorithm: linear equation
# state_dim: 54, action_dim: 3, fast algorithm: linear equation
# state_dim: 54, action_dim: 4, fast algorithm: policy iteration
# state_dim: 54, action_dim: 5, fast algorithm: linear equation
# state_dim: 54, action_dim: 6, fast algorithm: linear equation
# state_dim: 54, action_dim: 7, fast algorithm: linear equation
# state_dim: 54, action_dim: 8, fast algorithm: linear equation
# state_dim: 54, action_dim: 9, fast algorithm: linear equation
# state_dim: 55, action_dim: 1, fast algorithm: policy iteration
# state_dim: 55, action_dim: 2, fast algorithm: linear equation
# state_dim: 55, action_dim: 3, fast algorithm: linear equation
# state_dim: 55, action_dim: 4, fast algorithm: linear equation
# state_dim: 55, action_dim: 5, fast algorithm: linear equation
# state_dim: 55, action_dim: 6, fast algorithm: linear equation
# state_dim: 55, action_dim: 7, fast algorithm: linear equation
# state_dim: 55, action_dim: 8, fast algorithm: linear equation
# state_dim: 55, action_dim: 9, fast algorithm: linear equation
# state_dim: 56, action_dim: 1, fast algorithm: policy iteration
# state_dim: 56, action_dim: 2, fast algorithm: linear equation
# state_dim: 56, action_dim: 3, fast algorithm: linear equation
# state_dim: 56, action_dim: 4, fast algorithm: linear equation
# state_dim: 56, action_dim: 5, fast algorithm: policy iteration
# state_dim: 56, action_dim: 6, fast algorithm: linear equation
# state_dim: 56, action_dim: 7, fast algorithm: linear equation
# state_dim: 56, action_dim: 8, fast algorithm: linear equation
# state_dim: 56, action_dim: 9, fast algorithm: linear equation
# state_dim: 57, action_dim: 1, fast algorithm: policy iteration
# state_dim: 57, action_dim: 2, fast algorithm: linear equation
# state_dim: 57, action_dim: 3, fast algorithm: linear equation
# state_dim: 57, action_dim: 4, fast algorithm: linear equation
# state_dim: 57, action_dim: 5, fast algorithm: linear equation
# state_dim: 57, action_dim: 6, fast algorithm: linear equation
# state_dim: 57, action_dim: 7, fast algorithm: linear equation
# state_dim: 57, action_dim: 8, fast algorithm: linear equation
# state_dim: 57, action_dim: 9, fast algorithm: policy iteration
# state_dim: 58, action_dim: 1, fast algorithm: policy iteration
# state_dim: 58, action_dim: 2, fast algorithm: linear equation
# state_dim: 58, action_dim: 3, fast algorithm: linear equation
# state_dim: 58, action_dim: 4, fast algorithm: linear equation
# state_dim: 58, action_dim: 5, fast algorithm: linear equation
# state_dim: 58, action_dim: 6, fast algorithm: linear equation
# state_dim: 58, action_dim: 7, fast algorithm: linear equation
# state_dim: 58, action_dim: 8, fast algorithm: linear equation
# state_dim: 58, action_dim: 9, fast algorithm: linear equation
# state_dim: 59, action_dim: 1, fast algorithm: policy iteration
# state_dim: 59, action_dim: 2, fast algorithm: linear equation
# state_dim: 59, action_dim: 3, fast algorithm: linear equation
# state_dim: 59, action_dim: 4, fast algorithm: linear equation
# state_dim: 59, action_dim: 5, fast algorithm: linear equation
# state_dim: 59, action_dim: 6, fast algorithm: linear equation
# state_dim: 59, action_dim: 7, fast algorithm: linear equation
# state_dim: 59, action_dim: 8, fast algorithm: linear equation
# state_dim: 59, action_dim: 9, fast algorithm: linear equation
# state_dim: 60, action_dim: 1, fast algorithm: policy iteration
# state_dim: 60, action_dim: 2, fast algorithm: linear equation
# state_dim: 60, action_dim: 3, fast algorithm: linear equation
# state_dim: 60, action_dim: 4, fast algorithm: linear equation
# state_dim: 60, action_dim: 5, fast algorithm: linear equation
# state_dim: 60, action_dim: 6, fast algorithm: linear equation
# state_dim: 60, action_dim: 7, fast algorithm: linear equation
# state_dim: 60, action_dim: 8, fast algorithm: linear equation
# state_dim: 60, action_dim: 9, fast algorithm: policy iteration
# state_dim: 61, action_dim: 1, fast algorithm: policy iteration
# state_dim: 61, action_dim: 2, fast algorithm: linear equation
# state_dim: 61, action_dim: 3, fast algorithm: linear equation
# state_dim: 61, action_dim: 4, fast algorithm: linear equation
# state_dim: 61, action_dim: 5, fast algorithm: linear equation
# state_dim: 61, action_dim: 6, fast algorithm: linear equation
# state_dim: 61, action_dim: 7, fast algorithm: linear equation
# state_dim: 61, action_dim: 8, fast algorithm: linear equation
# state_dim: 61, action_dim: 9, fast algorithm: linear equation
# state_dim: 62, action_dim: 1, fast algorithm: policy iteration
# state_dim: 62, action_dim: 2, fast algorithm: linear equation
# state_dim: 62, action_dim: 3, fast algorithm: linear equation
# state_dim: 62, action_dim: 4, fast algorithm: linear equation
# state_dim: 62, action_dim: 5, fast algorithm: linear equation
# state_dim: 62, action_dim: 6, fast algorithm: linear equation
# state_dim: 62, action_dim: 7, fast algorithm: linear equation
# state_dim: 62, action_dim: 8, fast algorithm: linear equation
# state_dim: 62, action_dim: 9, fast algorithm: linear equation
# state_dim: 63, action_dim: 1, fast algorithm: policy iteration
# state_dim: 63, action_dim: 2, fast algorithm: linear equation
# state_dim: 63, action_dim: 3, fast algorithm: linear equation
# state_dim: 63, action_dim: 4, fast algorithm: linear equation
# state_dim: 63, action_dim: 5, fast algorithm: linear equation
# state_dim: 63, action_dim: 6, fast algorithm: linear equation
# state_dim: 63, action_dim: 7, fast algorithm: linear equation
# state_dim: 63, action_dim: 8, fast algorithm: linear equation
# state_dim: 63, action_dim: 9, fast algorithm: linear equation
# state_dim: 64, action_dim: 1, fast algorithm: policy iteration
# state_dim: 64, action_dim: 2, fast algorithm: linear equation
# state_dim: 64, action_dim: 3, fast algorithm: linear equation
# state_dim: 64, action_dim: 4, fast algorithm: linear equation
# state_dim: 64, action_dim: 5, fast algorithm: linear equation
# state_dim: 64, action_dim: 6, fast algorithm: linear equation
# state_dim: 64, action_dim: 7, fast algorithm: linear equation
# state_dim: 64, action_dim: 8, fast algorithm: linear equation
# state_dim: 64, action_dim: 9, fast algorithm: linear equation
# state_dim: 65, action_dim: 1, fast algorithm: policy iteration
# state_dim: 65, action_dim: 2, fast algorithm: linear equation
# state_dim: 65, action_dim: 3, fast algorithm: linear equation
# state_dim: 65, action_dim: 4, fast algorithm: linear equation
# state_dim: 65, action_dim: 5, fast algorithm: linear equation
# state_dim: 65, action_dim: 6, fast algorithm: linear equation
# state_dim: 65, action_dim: 7, fast algorithm: linear equation
# state_dim: 65, action_dim: 8, fast algorithm: linear equation
# state_dim: 65, action_dim: 9, fast algorithm: linear equation
# state_dim: 66, action_dim: 1, fast algorithm: policy iteration
# state_dim: 66, action_dim: 2, fast algorithm: linear equation
# state_dim: 66, action_dim: 3, fast algorithm: linear equation
# state_dim: 66, action_dim: 4, fast algorithm: linear equation
# state_dim: 66, action_dim: 5, fast algorithm: linear equation
# state_dim: 66, action_dim: 6, fast algorithm: linear equation
# state_dim: 66, action_dim: 7, fast algorithm: linear equation
# state_dim: 66, action_dim: 8, fast algorithm: linear equation
# state_dim: 66, action_dim: 9, fast algorithm: linear equation
# state_dim: 67, action_dim: 1, fast algorithm: policy iteration
# state_dim: 67, action_dim: 2, fast algorithm: linear equation
# state_dim: 67, action_dim: 3, fast algorithm: linear equation
# state_dim: 67, action_dim: 4, fast algorithm: linear equation
# state_dim: 67, action_dim: 5, fast algorithm: linear equation
# state_dim: 67, action_dim: 6, fast algorithm: linear equation
# state_dim: 67, action_dim: 7, fast algorithm: linear equation
# state_dim: 67, action_dim: 8, fast algorithm: linear equation
# state_dim: 67, action_dim: 9, fast algorithm: linear equation
# state_dim: 68, action_dim: 1, fast algorithm: policy iteration
# state_dim: 68, action_dim: 2, fast algorithm: linear equation
# state_dim: 68, action_dim: 3, fast algorithm: linear equation
# state_dim: 68, action_dim: 4, fast algorithm: linear equation
# state_dim: 68, action_dim: 5, fast algorithm: linear equation
# state_dim: 68, action_dim: 6, fast algorithm: linear equation
# state_dim: 68, action_dim: 7, fast algorithm: linear equation
# state_dim: 68, action_dim: 8, fast algorithm: linear equation
# state_dim: 68, action_dim: 9, fast algorithm: linear equation
# state_dim: 69, action_dim: 1, fast algorithm: policy iteration
# state_dim: 69, action_dim: 2, fast algorithm: linear equation
# state_dim: 69, action_dim: 3, fast algorithm: linear equation
# state_dim: 69, action_dim: 4, fast algorithm: linear equation
# state_dim: 69, action_dim: 5, fast algorithm: linear equation
# state_dim: 69, action_dim: 6, fast algorithm: linear equation
# state_dim: 69, action_dim: 7, fast algorithm: linear equation
# state_dim: 69, action_dim: 8, fast algorithm: policy iteration
# state_dim: 69, action_dim: 9, fast algorithm: linear equation
# state_dim: 70, action_dim: 1, fast algorithm: policy iteration
# state_dim: 70, action_dim: 2, fast algorithm: linear equation
# state_dim: 70, action_dim: 3, fast algorithm: linear equation
# state_dim: 70, action_dim: 4, fast algorithm: linear equation
# state_dim: 70, action_dim: 5, fast algorithm: linear equation
# state_dim: 70, action_dim: 6, fast algorithm: linear equation
# state_dim: 70, action_dim: 7, fast algorithm: linear equation
# state_dim: 70, action_dim: 8, fast algorithm: linear equation
# state_dim: 70, action_dim: 9, fast algorithm: linear equation
# state_dim: 71, action_dim: 1, fast algorithm: policy iteration
# state_dim: 71, action_dim: 2, fast algorithm: linear equation
# state_dim: 71, action_dim: 3, fast algorithm: linear equation
# state_dim: 71, action_dim: 4, fast algorithm: linear equation
# state_dim: 71, action_dim: 5, fast algorithm: linear equation
# state_dim: 71, action_dim: 6, fast algorithm: linear equation
# state_dim: 71, action_dim: 7, fast algorithm: linear equation
# state_dim: 71, action_dim: 8, fast algorithm: linear equation
# state_dim: 71, action_dim: 9, fast algorithm: linear equation
# state_dim: 72, action_dim: 1, fast algorithm: policy iteration
# state_dim: 72, action_dim: 2, fast algorithm: linear equation
# state_dim: 72, action_dim: 3, fast algorithm: linear equation
# state_dim: 72, action_dim: 4, fast algorithm: linear equation
# state_dim: 72, action_dim: 5, fast algorithm: linear equation
# state_dim: 72, action_dim: 6, fast algorithm: linear equation
# state_dim: 72, action_dim: 7, fast algorithm: linear equation
# state_dim: 72, action_dim: 8, fast algorithm: linear equation
# state_dim: 72, action_dim: 9, fast algorithm: linear equation
# state_dim: 73, action_dim: 1, fast algorithm: policy iteration
# state_dim: 73, action_dim: 2, fast algorithm: linear equation
# state_dim: 73, action_dim: 3, fast algorithm: linear equation
# state_dim: 73, action_dim: 4, fast algorithm: linear equation
# state_dim: 73, action_dim: 5, fast algorithm: linear equation
# state_dim: 73, action_dim: 6, fast algorithm: linear equation
# state_dim: 73, action_dim: 7, fast algorithm: linear equation
# state_dim: 73, action_dim: 8, fast algorithm: linear equation
# state_dim: 73, action_dim: 9, fast algorithm: linear equation
# state_dim: 74, action_dim: 1, fast algorithm: policy iteration
# state_dim: 74, action_dim: 2, fast algorithm: policy iteration
# state_dim: 74, action_dim: 3, fast algorithm: linear equation
# state_dim: 74, action_dim: 4, fast algorithm: linear equation
# state_dim: 74, action_dim: 5, fast algorithm: linear equation
# state_dim: 74, action_dim: 6, fast algorithm: linear equation
# state_dim: 74, action_dim: 7, fast algorithm: linear equation
# state_dim: 74, action_dim: 8, fast algorithm: linear equation
# state_dim: 74, action_dim: 9, fast algorithm: linear equation
# state_dim: 75, action_dim: 1, fast algorithm: policy iteration
# state_dim: 75, action_dim: 2, fast algorithm: linear equation
# state_dim: 75, action_dim: 3, fast algorithm: linear equation
# state_dim: 75, action_dim: 4, fast algorithm: policy iteration
# state_dim: 75, action_dim: 5, fast algorithm: linear equation
# state_dim: 75, action_dim: 6, fast algorithm: linear equation
# state_dim: 75, action_dim: 7, fast algorithm: linear equation
# state_dim: 75, action_dim: 8, fast algorithm: linear equation
# state_dim: 75, action_dim: 9, fast algorithm: linear equation
# state_dim: 76, action_dim: 1, fast algorithm: policy iteration
# state_dim: 76, action_dim: 2, fast algorithm: linear equation
# state_dim: 76, action_dim: 3, fast algorithm: linear equation
# state_dim: 76, action_dim: 4, fast algorithm: linear equation
# state_dim: 76, action_dim: 5, fast algorithm: linear equation
# state_dim: 76, action_dim: 6, fast algorithm: linear equation
# state_dim: 76, action_dim: 7, fast algorithm: linear equation
# state_dim: 76, action_dim: 8, fast algorithm: linear equation
# state_dim: 76, action_dim: 9, fast algorithm: policy iteration
# state_dim: 77, action_dim: 1, fast algorithm: policy iteration
# state_dim: 77, action_dim: 2, fast algorithm: linear equation
# state_dim: 77, action_dim: 3, fast algorithm: linear equation
# state_dim: 77, action_dim: 4, fast algorithm: linear equation
# state_dim: 77, action_dim: 5, fast algorithm: linear equation
# state_dim: 77, action_dim: 6, fast algorithm: linear equation
# state_dim: 77, action_dim: 7, fast algorithm: linear equation
# state_dim: 77, action_dim: 8, fast algorithm: linear equation
# state_dim: 77, action_dim: 9, fast algorithm: linear equation
# state_dim: 78, action_dim: 1, fast algorithm: policy iteration
# state_dim: 78, action_dim: 2, fast algorithm: linear equation
# state_dim: 78, action_dim: 3, fast algorithm: linear equation
# state_dim: 78, action_dim: 4, fast algorithm: linear equation
# state_dim: 78, action_dim: 5, fast algorithm: linear equation
# state_dim: 78, action_dim: 6, fast algorithm: linear equation
# state_dim: 78, action_dim: 7, fast algorithm: linear equation
# state_dim: 78, action_dim: 8, fast algorithm: linear equation
# state_dim: 78, action_dim: 9, fast algorithm: linear equation
# state_dim: 79, action_dim: 1, fast algorithm: policy iteration
# state_dim: 79, action_dim: 2, fast algorithm: linear equation
# state_dim: 79, action_dim: 3, fast algorithm: linear equation
# state_dim: 79, action_dim: 4, fast algorithm: linear equation
# state_dim: 79, action_dim: 5, fast algorithm: linear equation
# state_dim: 79, action_dim: 6, fast algorithm: linear equation
# state_dim: 79, action_dim: 7, fast algorithm: linear equation
# state_dim: 79, action_dim: 8, fast algorithm: linear equation
# state_dim: 79, action_dim: 9, fast algorithm: linear equation
# state_dim: 80, action_dim: 1, fast algorithm: policy iteration
# state_dim: 80, action_dim: 2, fast algorithm: linear equation
# state_dim: 80, action_dim: 3, fast algorithm: linear equation
# state_dim: 80, action_dim: 4, fast algorithm: linear equation
# state_dim: 80, action_dim: 5, fast algorithm: linear equation
# state_dim: 80, action_dim: 6, fast algorithm: linear equation
# state_dim: 80, action_dim: 7, fast algorithm: linear equation
# state_dim: 80, action_dim: 8, fast algorithm: linear equation
# state_dim: 80, action_dim: 9, fast algorithm: linear equation
# state_dim: 81, action_dim: 1, fast algorithm: policy iteration
# state_dim: 81, action_dim: 2, fast algorithm: linear equation
# state_dim: 81, action_dim: 3, fast algorithm: linear equation
# state_dim: 81, action_dim: 4, fast algorithm: linear equation
# state_dim: 81, action_dim: 5, fast algorithm: linear equation
# state_dim: 81, action_dim: 6, fast algorithm: linear equation
# state_dim: 81, action_dim: 7, fast algorithm: linear equation
# state_dim: 81, action_dim: 8, fast algorithm: linear equation
# state_dim: 81, action_dim: 9, fast algorithm: linear equation
# state_dim: 82, action_dim: 1, fast algorithm: policy iteration
# state_dim: 82, action_dim: 2, fast algorithm: linear equation
# state_dim: 82, action_dim: 3, fast algorithm: linear equation
# state_dim: 82, action_dim: 4, fast algorithm: linear equation
# state_dim: 82, action_dim: 5, fast algorithm: linear equation
# state_dim: 82, action_dim: 6, fast algorithm: linear equation
# state_dim: 82, action_dim: 7, fast algorithm: linear equation
# state_dim: 82, action_dim: 8, fast algorithm: policy iteration
# state_dim: 82, action_dim: 9, fast algorithm: linear equation
# state_dim: 83, action_dim: 1, fast algorithm: policy iteration
# state_dim: 83, action_dim: 2, fast algorithm: linear equation
# state_dim: 83, action_dim: 3, fast algorithm: policy iteration
# state_dim: 83, action_dim: 4, fast algorithm: policy iteration
# state_dim: 83, action_dim: 5, fast algorithm: linear equation
# state_dim: 83, action_dim: 6, fast algorithm: linear equation
# state_dim: 83, action_dim: 7, fast algorithm: linear equation
# state_dim: 83, action_dim: 8, fast algorithm: linear equation
# state_dim: 83, action_dim: 9, fast algorithm: linear equation
# state_dim: 84, action_dim: 1, fast algorithm: policy iteration
# state_dim: 84, action_dim: 2, fast algorithm: linear equation
# state_dim: 84, action_dim: 3, fast algorithm: linear equation
# state_dim: 84, action_dim: 4, fast algorithm: linear equation
# state_dim: 84, action_dim: 5, fast algorithm: linear equation
# state_dim: 84, action_dim: 6, fast algorithm: policy iteration
# state_dim: 84, action_dim: 7, fast algorithm: linear equation
# state_dim: 84, action_dim: 8, fast algorithm: linear equation
# state_dim: 84, action_dim: 9, fast algorithm: linear equation
# state_dim: 85, action_dim: 1, fast algorithm: policy iteration
# state_dim: 85, action_dim: 2, fast algorithm: policy iteration
# state_dim: 85, action_dim: 3, fast algorithm: linear equation
# state_dim: 85, action_dim: 4, fast algorithm: linear equation
# state_dim: 85, action_dim: 5, fast algorithm: linear equation
# state_dim: 85, action_dim: 6, fast algorithm: linear equation
# state_dim: 85, action_dim: 7, fast algorithm: linear equation
# state_dim: 85, action_dim: 8, fast algorithm: linear equation
# state_dim: 85, action_dim: 9, fast algorithm: linear equation
# state_dim: 86, action_dim: 1, fast algorithm: policy iteration
# state_dim: 86, action_dim: 2, fast algorithm: policy iteration
# state_dim: 86, action_dim: 3, fast algorithm: linear equation
# state_dim: 86, action_dim: 4, fast algorithm: linear equation
# state_dim: 86, action_dim: 5, fast algorithm: linear equation
# state_dim: 86, action_dim: 6, fast algorithm: linear equation
# state_dim: 86, action_dim: 7, fast algorithm: linear equation
# state_dim: 86, action_dim: 8, fast algorithm: linear equation
# state_dim: 86, action_dim: 9, fast algorithm: linear equation
# ...
# state_dim: 972, action_dim: 1, fast algorithm: policy iteration
# state_dim: 972, action_dim: 2, fast algorithm: policy iteration
# state_dim: 972, action_dim: 3, fast algorithm: policy iteration
# state_dim: 972, action_dim: 4, fast algorithm: linear equation
# state_dim: 972, action_dim: 5, fast algorithm: linear equation
# state_dim: 972, action_dim: 6, fast algorithm: linear equation
# state_dim: 972, action_dim: 7, fast algorithm: linear equation
# state_dim: 972, action_dim: 8, fast algorithm: linear equation
# state_dim: 972, action_dim: 9, fast algorithm: linear equation
# state_dim: 973, action_dim: 1, fast algorithm: policy iteration
# state_dim: 973, action_dim: 2, fast algorithm: policy iteration
# state_dim: 973, action_dim: 3, fast algorithm: policy iteration
# state_dim: 973, action_dim: 4, fast algorithm: linear equation
# state_dim: 973, action_dim: 5, fast algorithm: linear equation
# state_dim: 973, action_dim: 6, fast algorithm: linear equation
# state_dim: 973, action_dim: 7, fast algorithm: linear equation
# state_dim: 973, action_dim: 8, fast algorithm: linear equation
# state_dim: 973, action_dim: 9, fast algorithm: linear equation
# state_dim: 974, action_dim: 1, fast algorithm: policy iteration
# state_dim: 974, action_dim: 2, fast algorithm: policy iteration
# state_dim: 974, action_dim: 3, fast algorithm: policy iteration
# state_dim: 974, action_dim: 4, fast algorithm: linear equation
# state_dim: 974, action_dim: 5, fast algorithm: linear equation
# state_dim: 974, action_dim: 6, fast algorithm: linear equation
# state_dim: 974, action_dim: 7, fast algorithm: linear equation
# state_dim: 974, action_dim: 8, fast algorithm: linear equation
# state_dim: 974, action_dim: 9, fast algorithm: linear equation
# state_dim: 975, action_dim: 1, fast algorithm: policy iteration
# state_dim: 975, action_dim: 2, fast algorithm: policy iteration
# state_dim: 975, action_dim: 3, fast algorithm: linear equation
# state_dim: 975, action_dim: 4, fast algorithm: linear equation
# state_dim: 975, action_dim: 5, fast algorithm: linear equation
# state_dim: 975, action_dim: 6, fast algorithm: linear equation
# state_dim: 975, action_dim: 7, fast algorithm: linear equation
# state_dim: 975, action_dim: 8, fast algorithm: linear equation
# state_dim: 975, action_dim: 9, fast algorithm: linear equation
# state_dim: 976, action_dim: 1, fast algorithm: policy iteration
# state_dim: 976, action_dim: 2, fast algorithm: policy iteration
# state_dim: 976, action_dim: 3, fast algorithm: linear equation
# state_dim: 976, action_dim: 4, fast algorithm: linear equation
# state_dim: 976, action_dim: 5, fast algorithm: linear equation
# state_dim: 976, action_dim: 6, fast algorithm: linear equation
# state_dim: 976, action_dim: 7, fast algorithm: linear equation
# state_dim: 976, action_dim: 8, fast algorithm: linear equation
# state_dim: 976, action_dim: 9, fast algorithm: linear equation
# state_dim: 977, action_dim: 1, fast algorithm: policy iteration
# state_dim: 977, action_dim: 2, fast algorithm: policy iteration
# state_dim: 977, action_dim: 3, fast algorithm: policy iteration
# state_dim: 977, action_dim: 4, fast algorithm: linear equation
# state_dim: 977, action_dim: 5, fast algorithm: linear equation
# state_dim: 977, action_dim: 6, fast algorithm: linear equation
# state_dim: 977, action_dim: 7, fast algorithm: linear equation
# state_dim: 977, action_dim: 8, fast algorithm: linear equation
# state_dim: 977, action_dim: 9, fast algorithm: linear equation
# state_dim: 978, action_dim: 1, fast algorithm: policy iteration
# state_dim: 978, action_dim: 2, fast algorithm: policy iteration
# state_dim: 978, action_dim: 3, fast algorithm: policy iteration
# state_dim: 978, action_dim: 4, fast algorithm: linear equation
# state_dim: 978, action_dim: 5, fast algorithm: linear equation
# state_dim: 978, action_dim: 6, fast algorithm: linear equation
# state_dim: 978, action_dim: 7, fast algorithm: linear equation
# state_dim: 978, action_dim: 8, fast algorithm: linear equation
# state_dim: 978, action_dim: 9, fast algorithm: linear equation
# state_dim: 979, action_dim: 1, fast algorithm: policy iteration
# state_dim: 979, action_dim: 2, fast algorithm: policy iteration
# state_dim: 979, action_dim: 3, fast algorithm: policy iteration
# state_dim: 979, action_dim: 4, fast algorithm: linear equation
# state_dim: 979, action_dim: 5, fast algorithm: linear equation
# state_dim: 979, action_dim: 6, fast algorithm: linear equation
# state_dim: 979, action_dim: 7, fast algorithm: linear equation
# state_dim: 979, action_dim: 8, fast algorithm: linear equation
# state_dim: 979, action_dim: 9, fast algorithm: linear equation
# state_dim: 980, action_dim: 1, fast algorithm: policy iteration
# state_dim: 980, action_dim: 2, fast algorithm: policy iteration
# state_dim: 980, action_dim: 3, fast algorithm: policy iteration
# state_dim: 980, action_dim: 4, fast algorithm: linear equation
# state_dim: 980, action_dim: 5, fast algorithm: linear equation
# state_dim: 980, action_dim: 6, fast algorithm: linear equation
# state_dim: 980, action_dim: 7, fast algorithm: linear equation
# state_dim: 980, action_dim: 8, fast algorithm: linear equation
# state_dim: 980, action_dim: 9, fast algorithm: linear equation
# state_dim: 981, action_dim: 1, fast algorithm: policy iteration
# state_dim: 981, action_dim: 2, fast algorithm: policy iteration
# state_dim: 981, action_dim: 3, fast algorithm: policy iteration
# state_dim: 981, action_dim: 4, fast algorithm: linear equation
# state_dim: 981, action_dim: 5, fast algorithm: linear equation
# state_dim: 981, action_dim: 6, fast algorithm: linear equation
# state_dim: 981, action_dim: 7, fast algorithm: linear equation
# state_dim: 981, action_dim: 8, fast algorithm: linear equation
# state_dim: 981, action_dim: 9, fast algorithm: linear equation
# state_dim: 982, action_dim: 1, fast algorithm: policy iteration
# state_dim: 982, action_dim: 2, fast algorithm: policy iteration
# state_dim: 982, action_dim: 3, fast algorithm: policy iteration
# state_dim: 982, action_dim: 4, fast algorithm: linear equation
# state_dim: 982, action_dim: 5, fast algorithm: linear equation
# state_dim: 982, action_dim: 6, fast algorithm: linear equation
# state_dim: 982, action_dim: 7, fast algorithm: linear equation
# state_dim: 982, action_dim: 8, fast algorithm: linear equation
# state_dim: 982, action_dim: 9, fast algorithm: linear equation
# state_dim: 983, action_dim: 1, fast algorithm: policy iteration
# state_dim: 983, action_dim: 2, fast algorithm: policy iteration
# state_dim: 983, action_dim: 3, fast algorithm: policy iteration
# state_dim: 983, action_dim: 4, fast algorithm: linear equation
# state_dim: 983, action_dim: 5, fast algorithm: linear equation
# state_dim: 983, action_dim: 6, fast algorithm: linear equation
# state_dim: 983, action_dim: 7, fast algorithm: linear equation
# state_dim: 983, action_dim: 8, fast algorithm: linear equation
# state_dim: 983, action_dim: 9, fast algorithm: linear equation
# state_dim: 984, action_dim: 1, fast algorithm: policy iteration
# state_dim: 984, action_dim: 2, fast algorithm: policy iteration
# state_dim: 984, action_dim: 3, fast algorithm: linear equation
# state_dim: 984, action_dim: 4, fast algorithm: linear equation
# state_dim: 984, action_dim: 5, fast algorithm: linear equation
# state_dim: 984, action_dim: 6, fast algorithm: linear equation
# state_dim: 984, action_dim: 7, fast algorithm: linear equation
# state_dim: 984, action_dim: 8, fast algorithm: linear equation
# state_dim: 984, action_dim: 9, fast algorithm: linear equation
# state_dim: 985, action_dim: 1, fast algorithm: policy iteration
# state_dim: 985, action_dim: 2, fast algorithm: policy iteration
# state_dim: 985, action_dim: 3, fast algorithm: policy iteration
# state_dim: 985, action_dim: 4, fast algorithm: linear equation
# state_dim: 985, action_dim: 5, fast algorithm: linear equation
# state_dim: 985, action_dim: 6, fast algorithm: linear equation
# state_dim: 985, action_dim: 7, fast algorithm: linear equation
# state_dim: 985, action_dim: 8, fast algorithm: linear equation
# state_dim: 985, action_dim: 9, fast algorithm: linear equation
# state_dim: 986, action_dim: 1, fast algorithm: policy iteration
# state_dim: 986, action_dim: 2, fast algorithm: policy iteration
# state_dim: 986, action_dim: 3, fast algorithm: policy iteration
# state_dim: 986, action_dim: 4, fast algorithm: linear equation
# state_dim: 986, action_dim: 5, fast algorithm: linear equation
# state_dim: 986, action_dim: 6, fast algorithm: linear equation
# state_dim: 986, action_dim: 7, fast algorithm: linear equation
# state_dim: 986, action_dim: 8, fast algorithm: linear equation
# state_dim: 986, action_dim: 9, fast algorithm: linear equation
# state_dim: 987, action_dim: 1, fast algorithm: policy iteration
# state_dim: 987, action_dim: 2, fast algorithm: policy iteration
# state_dim: 987, action_dim: 3, fast algorithm: policy iteration
# state_dim: 987, action_dim: 4, fast algorithm: linear equation
# state_dim: 987, action_dim: 5, fast algorithm: linear equation
# state_dim: 987, action_dim: 6, fast algorithm: linear equation
# state_dim: 987, action_dim: 7, fast algorithm: linear equation
# state_dim: 987, action_dim: 8, fast algorithm: linear equation
# state_dim: 987, action_dim: 9, fast algorithm: linear equation
# state_dim: 988, action_dim: 1, fast algorithm: policy iteration
# state_dim: 988, action_dim: 2, fast algorithm: policy iteration
# state_dim: 988, action_dim: 3, fast algorithm: policy iteration
# state_dim: 988, action_dim: 4, fast algorithm: linear equation
# state_dim: 988, action_dim: 5, fast algorithm: linear equation
# state_dim: 988, action_dim: 6, fast algorithm: linear equation
# state_dim: 988, action_dim: 7, fast algorithm: linear equation
# state_dim: 988, action_dim: 8, fast algorithm: linear equation
# state_dim: 988, action_dim: 9, fast algorithm: linear equation
# state_dim: 989, action_dim: 1, fast algorithm: policy iteration
# state_dim: 989, action_dim: 2, fast algorithm: policy iteration
# state_dim: 989, action_dim: 3, fast algorithm: policy iteration
# state_dim: 989, action_dim: 4, fast algorithm: linear equation
# state_dim: 989, action_dim: 5, fast algorithm: linear equation
# state_dim: 989, action_dim: 6, fast algorithm: linear equation
# state_dim: 989, action_dim: 7, fast algorithm: linear equation
# state_dim: 989, action_dim: 8, fast algorithm: linear equation
# state_dim: 989, action_dim: 9, fast algorithm: linear equation
# state_dim: 990, action_dim: 1, fast algorithm: policy iteration
# state_dim: 990, action_dim: 2, fast algorithm: policy iteration
# state_dim: 990, action_dim: 3, fast algorithm: policy iteration
# state_dim: 990, action_dim: 4, fast algorithm: linear equation
# state_dim: 990, action_dim: 5, fast algorithm: linear equation
# state_dim: 990, action_dim: 6, fast algorithm: linear equation
# state_dim: 990, action_dim: 7, fast algorithm: linear equation
# state_dim: 990, action_dim: 8, fast algorithm: linear equation
# state_dim: 990, action_dim: 9, fast algorithm: linear equation
# state_dim: 991, action_dim: 1, fast algorithm: policy iteration
# state_dim: 991, action_dim: 2, fast algorithm: policy iteration
# state_dim: 991, action_dim: 3, fast algorithm: policy iteration
# state_dim: 991, action_dim: 4, fast algorithm: linear equation
# state_dim: 991, action_dim: 5, fast algorithm: linear equation
# state_dim: 991, action_dim: 6, fast algorithm: linear equation
# state_dim: 991, action_dim: 7, fast algorithm: linear equation
# state_dim: 991, action_dim: 8, fast algorithm: linear equation
# state_dim: 991, action_dim: 9, fast algorithm: linear equation
# state_dim: 992, action_dim: 1, fast algorithm: policy iteration
# state_dim: 992, action_dim: 2, fast algorithm: policy iteration
# state_dim: 992, action_dim: 3, fast algorithm: linear equation
# state_dim: 992, action_dim: 4, fast algorithm: linear equation
# state_dim: 992, action_dim: 5, fast algorithm: linear equation
# state_dim: 992, action_dim: 6, fast algorithm: linear equation
# state_dim: 992, action_dim: 7, fast algorithm: linear equation
# state_dim: 992, action_dim: 8, fast algorithm: linear equation
# state_dim: 992, action_dim: 9, fast algorithm: linear equation
# state_dim: 993, action_dim: 1, fast algorithm: policy iteration
# state_dim: 993, action_dim: 2, fast algorithm: policy iteration
# state_dim: 993, action_dim: 3, fast algorithm: policy iteration
# state_dim: 993, action_dim: 4, fast algorithm: linear equation
# state_dim: 993, action_dim: 5, fast algorithm: linear equation
# state_dim: 993, action_dim: 6, fast algorithm: linear equation
# state_dim: 993, action_dim: 7, fast algorithm: linear equation
# state_dim: 993, action_dim: 8, fast algorithm: linear equation
# state_dim: 993, action_dim: 9, fast algorithm: linear equation
# state_dim: 994, action_dim: 1, fast algorithm: policy iteration
# state_dim: 994, action_dim: 2, fast algorithm: policy iteration
# state_dim: 994, action_dim: 3, fast algorithm: policy iteration
# state_dim: 994, action_dim: 4, fast algorithm: linear equation
# state_dim: 994, action_dim: 5, fast algorithm: linear equation
# state_dim: 994, action_dim: 6, fast algorithm: linear equation
# state_dim: 994, action_dim: 7, fast algorithm: linear equation
# state_dim: 994, action_dim: 8, fast algorithm: linear equation
# state_dim: 994, action_dim: 9, fast algorithm: linear equation
# state_dim: 995, action_dim: 1, fast algorithm: policy iteration
# state_dim: 995, action_dim: 2, fast algorithm: policy iteration
# state_dim: 995, action_dim: 3, fast algorithm: policy iteration
# state_dim: 995, action_dim: 4, fast algorithm: linear equation
# state_dim: 995, action_dim: 5, fast algorithm: linear equation
# state_dim: 995, action_dim: 6, fast algorithm: linear equation
# state_dim: 995, action_dim: 7, fast algorithm: linear equation
# state_dim: 995, action_dim: 8, fast algorithm: linear equation
# state_dim: 995, action_dim: 9, fast algorithm: linear equation
# state_dim: 996, action_dim: 1, fast algorithm: policy iteration
# state_dim: 996, action_dim: 2, fast algorithm: policy iteration
# state_dim: 996, action_dim: 3, fast algorithm: policy iteration
# state_dim: 996, action_dim: 4, fast algorithm: linear equation
# state_dim: 996, action_dim: 5, fast algorithm: linear equation
# state_dim: 996, action_dim: 6, fast algorithm: linear equation
# state_dim: 996, action_dim: 7, fast algorithm: linear equation
# state_dim: 996, action_dim: 8, fast algorithm: linear equation
# state_dim: 996, action_dim: 9, fast algorithm: linear equation
# state_dim: 997, action_dim: 1, fast algorithm: policy iteration
# state_dim: 997, action_dim: 2, fast algorithm: policy iteration
# state_dim: 997, action_dim: 3, fast algorithm: policy iteration
# state_dim: 997, action_dim: 4, fast algorithm: linear equation
# state_dim: 997, action_dim: 5, fast algorithm: linear equation
# state_dim: 997, action_dim: 6, fast algorithm: linear equation
# state_dim: 997, action_dim: 7, fast algorithm: linear equation
# state_dim: 997, action_dim: 8, fast algorithm: linear equation
# state_dim: 997, action_dim: 9, fast algorithm: linear equation
# state_dim: 998, action_dim: 1, fast algorithm: policy iteration
# state_dim: 998, action_dim: 2, fast algorithm: policy iteration
# state_dim: 998, action_dim: 3, fast algorithm: policy iteration
# state_dim: 998, action_dim: 4, fast algorithm: linear equation
# state_dim: 998, action_dim: 5, fast algorithm: linear equation
# state_dim: 998, action_dim: 6, fast algorithm: linear equation
# state_dim: 998, action_dim: 7, fast algorithm: linear equation
# state_dim: 998, action_dim: 8, fast algorithm: linear equation
# state_dim: 998, action_dim: 9, fast algorithm: linear equation
# state_dim: 999, action_dim: 1, fast algorithm: policy iteration
# state_dim: 999, action_dim: 2, fast algorithm: policy iteration
# state_dim: 999, action_dim: 3, fast algorithm: policy iteration
# state_dim: 999, action_dim: 4, fast algorithm: linear equation
# state_dim: 999, action_dim: 5, fast algorithm: linear equation
# state_dim: 999, action_dim: 6, fast algorithm: linear equation
# state_dim: 999, action_dim: 7, fast algorithm: linear equation
# state_dim: 999, action_dim: 8, fast algorithm: linear equation
# state_dim: 999, action_dim: 9, fast algorithm: linear equation
